# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments,Trainer
import numpy as np
# %pip install evaluate
import evaluate


dataset = load_dataset("sms_spam")

print(dataset)
# Out:
# Requirement already satisfied: evaluate in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (0.4.6)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (4.4.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (2.4.0)
# Requirement already satisfied: dill in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.10.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from evaluate) (0.36.0)
# Requirement already satisfied: packaging in c:\users\nairi\appdata\roaming\python\python311\site-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.0.0->evaluate) (3.20.1)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.0.0->evaluate) (22.0.0)
# Requirement already satisfied: httpx<1.0.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.2)
# Requirement already satisfied: anyio in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.12.0)
# Requirement already satisfied: certifi in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: idna in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\nairi\appdata\roaming\python\python311\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->evaluate) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->evaluate) (2.6.2)
# Requirement already satisfied: colorama in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\nairi\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# DatasetDict({
#     train: Dataset({
#         features: ['sms', 'label'],
#         num_rows: 5574
#     })
# })

# %%
split_dataset = dataset["train"].train_test_split(test_size=0.2, seed=42)
print(split_dataset)
train_dataset = split_dataset["train"]
test_dataset = split_dataset["test"]

print(train_dataset)
print(test_dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sms', 'label'],
#         num_rows: 4459
#     })
#     test: Dataset({
#         features: ['sms', 'label'],
#         num_rows: 1115
#     })
# })
# Dataset({
#     features: ['sms', 'label'],
#     num_rows: 4459
# })
# Dataset({
#     features: ['sms', 'label'],
#     num_rows: 1115
# })

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

def preprocess(examples):
    return tokenizer(
        examples["sms"],
        truncation=True,
        padding=False,
        max_length=128
    )

train_dataset = train_dataset.map(preprocess, batched=True)
test_dataset = test_dataset.map(preprocess, batched=True)

# %%
num_labels = dataset["train"].features["label"].num_classes

model = AutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=num_labels,
    id2label={0: "ham", 1: "spam"},
    label2id={"ham": 0, "spam": 1}
)

for param in model.bert.parameters():
    param.requires_grad = False

for param in model.bert.encoder.layer[-2:].parameters():
    param.requires_grad = True

for param in model.bert.pooler.parameters():
    param.requires_grad = True
    
for param in model.classifier.parameters():
    param.requires_grad = True
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import evaluate
import numpy as np
accuracy_metrics = evaluate.load("accuracy")
def compute_metrics(eval_pred):
  logits,labels = eval_pred
  predictions = np.argmax(logits, axis=1)
  return accuracy_metrics.compute(predictions=predictions,references=labels)

# %%
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="no",

    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    weight_decay=0.01,

    report_to="none"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
# Out:
# C:\Users\nairi\AppData\Local\Temp\ipykernel_14824\3747196812.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# c:\Users\nairi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='837' max='837' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [837/837 29:41, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.039156</td>
#       <td>0.990135</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.084000</td>
#       <td>0.034777</td>
#       <td>0.992825</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.084000</td>
#       <td>0.035252</td>
#       <td>0.992825</td>
#     </tr>
#   </tbody>
# </table><p>
# c:\Users\nairi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\nairi\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=837, training_loss=0.06107061994545776, metrics={'train_runtime': 1784.1181, 'train_samples_per_second': 7.498, 'train_steps_per_second': 0.469, 'total_flos': 434916921733500.0, 'train_loss': 0.06107061994545776, 'epoch': 3.0})

# %%
save_dir = "./spam_classifier"

trainer.save_model(save_dir)
